# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV
df = pd.read_csv("runebound_depths_synthetic_10000.csv")

# Sample first 10 rows
sample = df.head(10)

# Plot and save as image
fig, ax = plt.subplots()
ax.axis('off')  # no axes
tbl = ax.table(cellText=sample.values, colLabels=sample.columns, loc='center')
plt.tight_layout()
plt.savefig("csv_sample.png", dpi=300)
